# %% [markdown]
# <a href="https://colab.research.google.com/github/seojh1047/10710/blob/main/20260908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
redCount=int(input('빨간색 접시의 개수를 입력하세요.'))
yellowCount=int(input('노란색 접시의 개수를 입력하세요.'))
blueCount=int(input('파란색 접시의 개수를 입력하세요.'))
greenCount=int(input('초록색 접시의 개수를 입력하세요.'))
print('=====회전초밥 영수증=====')
print('접시')
# Out:
# 빨간색 접시의 개수를 입력하세요.2
# 노란색 접시의 개수를 입력하세요.1
# 파란색 접시의 개수를 입력하세요.1
# 초록색 접시의 개수를 입력하세요.2
# =====회전초밥 영수증=====
# 접시
