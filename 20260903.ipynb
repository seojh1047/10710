# %% [markdown]
# <a href="https://colab.research.google.com/github/seojh1047/10710/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3 + 7)
print('3 + 7')
print(10, 20, 30, '정보', '프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3 + 7
# 10 20 30 정보 프로그래밍

# %%
print('한양과학기술고등학교', '1학년', '서준혁')
print()

# %%
a = 20
b = 50
print('현재 온도는 %d도, 습도는 %d%% 입니다.'%(a, b))
# Out:
# 현재 온도는 20도, 습도는 50% 입니다.

# %%
c = 90
d = 3.141592
print(f'직각은 {c}도, 원주율은 {d:0.2f}입니다.')
# Out:
# 직각은 90도, 원주율은 3.14입니다.

# %%
print('동해물과 ')

# %%
print('품목\t\t가격\t\t개수\n사과\t\t2.000\t\t8\n바나나\t\t3.000\t\t5\n')
# Out:
# 품목		가격		개수
# 사과		2.000		8
# 바나나		3.000		5

# %%
a = input('이름:')
b = input('나이:')
print(a, '님 안녕하세요?')
print(20-int(b), "년 후면 20살이시네요!")
# Out:
# 이름:서준혁
# 나이:17
# 서준혁 님 안녕하세요?
# 3 년 후면 20살이시네요!
