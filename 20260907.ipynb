# %% [markdown]
# <a href="https://colab.research.google.com/github/seojh1047/10710/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('<디데이(D-day) 프로그램>')
print( )
year = int(input('연도를 입력하세요: '))
month = int(input('월을 입력하세요: '))
day = int (input('일을 입력하세요: '))
dt4 = date(year. month. )
today = date.today( )             # today = 오늘 날짜 저장
dday = (dt4 - today).days         # dday = 두 날짜 시야의 일수 계산하여 저장
print(f'{year}년  {month}월 {day}일은 {dday}일 남았습니다.')
# Out:
#   File "/tmp/ipykernel_1208/3490940537.py", line 6
#     dt4 = date(year. month. )
#                             ^
# SyntaxError: invalid syntax
